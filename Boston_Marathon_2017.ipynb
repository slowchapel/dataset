# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_17 = pd.read_csv('df_17.csv')

# %%
df_17.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9   ...         25K      30K      35K      40K     Pace  \
# 0     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
df_17.dtypes
# Out:
# Unnamed: 0        int64
# Bib              object
# Name             object
# Age               int64
# M/F              object
# City             object
# State            object
# Country          object
# Citizen          object
# Unnamed: 9       object
# 5K               object
# 10K              object
# 15K              object
# 20K              object
# Half             object
# 25K              object
# 30K              object
# 35K              object
# 40K              object
# Pace             object
# Proj Time        object
# Official Time    object
# Overall           int64
# Gender            int64
# Division          int64
# dtype: object

# %% [markdown]
# ## Number of columns per dataset

# %%
print(f"{len(df_17.columns)} columns in Boston Marathon Results 2017")
# Out:
# 25 columns in Boston Marathon Results 2017

# %%
print(f"{len(df_17)} records in Boston Marathon Results 2017")
# Out:
# 26410 records in Boston Marathon Results 2017

# %% [markdown]
# ## Duplicate Rows

# %%
df_17.duplicated().sum()
# Out:
# 0

# %%
for k, v in df_17.iloc[0].items():
    print(f"{(k, v)}: {type(v)}")
# Out:
# ('Unnamed: 0', 0): <class 'numpy.int64'>
# ('Bib', '11'): <class 'str'>
# ('Name', 'Kirui, Geoffrey'): <class 'str'>
# ('Age', 24): <class 'numpy.int64'>
# ('M/F', 'M'): <class 'str'>
# ('City', 'Keringet'): <class 'str'>
# ('State', nan): <class 'float'>
# ('Country', 'KEN'): <class 'str'>
# ('Citizen', nan): <class 'float'>
# ('Unnamed: 9', nan): <class 'float'>
# ('5K', '0:15:25'): <class 'str'>
# ('10K', '0:30:28'): <class 'str'>
# ('15K', '0:45:44'): <class 'str'>
# ('20K', '1:01:15'): <class 'str'>
# ('Half', '1:04:35'): <class 'str'>
# ('25K', '1:16:59'): <class 'str'>
# ('30K', '1:33:01'): <class 'str'>
# ('35K', '1:48:19'): <class 'str'>
# ('40K', '2:02:53'): <class 'str'>
# ('Pace', '0:04:57'): <class 'str'>
# ('Proj Time', '-'): <class 'str'>
# ('Official Time', '2:09:37'): <class 'str'>
# ('Overall', 1): <class 'numpy.int64'>
# ('Gender', 1): <class 'numpy.int64'>
# ('Division', 1): <class 'numpy.int64'>

# %% [markdown]
# ## Features with missing values

# %%
df_17.isnull().sum()
# Out:
# Unnamed: 0           0
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 0
# State             3595
# Country              0
# Citizen          25156
# Unnamed: 9       26319
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time            0
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# dtype: int64

# %% [markdown]
# ## Non Null Values

# %%
df_17.nunique().sum()
# Out:
# 188656

# %% [markdown]
# ## Unique Citizen types

# %%
df_17.groupby('Citizen')['Citizen'].count()
# Out:
# Citizen
# ALB      1
# ARG     15
# AUS     35
# AUT      6
# AZE      1
# BAN      1
# BEL     12
# BIH      1
# BLR      1
# BRA     13
# BUL      2
# CAF      1
# CAM      1
# CAN    131
# CHI      6
# CHN     78
# COL     12
# CRC     10
# CUB      1
# CZE      9
# DEN     10
# DOM     10
# ECU      7
# EGY      1
# ESA      3
# ESP     27
# EST      2
# ETH      1
# FIN      5
# FRA     50
#       ...
# NED     25
# NGR      2
# NOR      5
# NZL     17
# PAK      2
# PER      2
# PHI     13
# POL     17
# POR      9
# ROU      4
# RSA     13
# RUS      6
# SIN      4
# SLO      2
# SRB      1
# SRI      1
# SUI     10
# SVK      2
# SWE     10
# THA      2
# TRI      2
# TUN      1
# TUR      4
# TWN      9
# UKR      4
# URU      4
# USA     74
# VEN     20
# ZAM      1
# ZIM      1
# Name: Citizen, Length: 85, dtype: int64

# %% [markdown]
# ## Drop Columns

# %%
df_17.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
df_17.drop(["Unnamed: 0", "Unnamed: 9"], axis=1, inplace=True)
df_17.head()
# Out:
#   Bib              Name  Age M/F           City State Country Citizen  \
# 0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN
# 1  17       Rupp, Galen   30   M       Portland    OR     USA     NaN
# 2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN
# 3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN
# 4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN
#
#         5K      10K   ...         25K      30K      35K      40K     Pace  \
# 0  0:15:25  0:30:28   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1  0:15:24  0:30:27   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2  0:15:25  0:30:29   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3  0:15:25  0:30:29   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4  0:15:25  0:30:28   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %% [markdown]
# ## Checkpoint

# %%
df_17.to_csv('df_17_v1.csv', index=False)

# %% [markdown]
# ## How many runners are from each state?

# %%
df_17.isnull().sum()
# Out:
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 0
# State             3595
# Country              0
# Citizen          25156
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time            0
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# dtype: int64

# %%
df_17['Name'].count()
# Out:
# 26410

# %%
df_17.groupby('State')['Name'].count()
# Out:
# State
# AA       1
# AB     169
# AE       5
# AK      52
# AL      80
# AP       2
# AR      56
# AZ     270
# BC     176
# CA    2049
# CO     534
# CT     377
# DC     156
# DE      47
# FL     609
# GA     317
# GU       1
# HI      37
# IA     111
# ID      93
# IL     771
# IN     267
# KS      92
# KY     138
# LA      88
# MA    4586
# MB      30
# MD     396
# ME     186
# MI     516
#       ...
# NH     324
# NJ     476
# NL      21
# NM      65
# NS      96
# NV      85
# NY    1324
# OH     693
# OK      81
# ON     820
# OR     312
# PA     842
# PE      14
# PR      21
# QC     468
# RI     136
# SC     136
# SD      34
# SK      17
# TN     237
# TX    1055
# UT     400
# VA     564
# VI       2
# VT      80
# WA     465
# WI     392
# WV      41
# WY      21
# YT       3
# Name: Name, Length: 68, dtype: int64

# %%
df_17.Age.value_counts()
# Out:
# 45    1127
# 46     976
# 40     926
# 47     843
# 50     815
# 41     801
# 35     800
# 48     784
# 42     758
# 36     733
# 39     712
# 43     706
# 37     687
# 49     686
# 55     682
# 38     670
# 51     658
# 44     651
# 52     638
# 29     636
# 30     629
# 33     591
# 28     590
# 31     583
# 53     573
# 27     571
# 32     563
# 26     557
# 34     540
# 56     504
#       ...
# 58     345
# 23     307
# 59     284
# 62     271
# 22     210
# 65     187
# 63     157
# 21     147
# 66     137
# 64     117
# 67     100
# 20      83
# 70      78
# 68      67
# 69      47
# 19      43
# 71      25
# 73      22
# 18      20
# 72      19
# 74      17
# 75      15
# 76      10
# 77       5
# 78       4
# 80       3
# 79       3
# 81       2
# 83       1
# 84       1
# Name: Age, Length: 66, dtype: int64

# %%
df_17.query('Age == "18"')
# Out:
#          Bib                  Name  Age M/F           City State Country  \
# 3748    5220     Eastmond, Riley J   18   M           Lehi    UT     USA
# 4084    3603           Fickes, Ben   18   M         Newark    DE     USA
# 4735    4496         Moore, Ryan D   18   M     North Bend    WA     USA
# 5443   27556       Umphrey, Duncan   18   M        Concord    MA     USA
# 7377    4083          Nelson, Alex   18   M       Redlands    CA     USA
# 8432   29072        Rezuke, Joseph   18   M     Shrewsbury    MA     USA
# 15919  15125        Rucker, Alyssa   18   F         Durham    NC     USA
# 15931  30496    Pohl, Elizabeth S.   18   F         Weston    MA     USA
# 16499  30146        Canzano, James   18   M     Shrewsbury    MA     USA
# 17735  26356       Fried, Lucas A.   18   M        Wayland    MA     USA
# 18487  28294     Georgaklis, Sofia   18   F      Brookline    MA     USA
# 21575  30213          Joy, Ryan A.   18   M  Chestnut Hill    MA     USA
# ...

# %%
df_17.query('Age == "84"')
# Out:
#          Bib               Name  Age M/F        City State Country Citizen  \
# 26340  25269  Beiers, Katherine   84   F  Santa Cruz    CA     USA     NaN
#
#             5K      10K   ...         25K      30K      35K      40K     Pace  \
# 26340  0:36:41  1:17:26   ...     3:25:20  4:12:04  4:58:00  5:43:44  0:13:54
#
#       Proj Time Official Time Overall Gender Division
# 26340         -       6:04:07   26342  11942        1
#
# [1 rows x 23 columns]

# %%
df_17.Age.hist();
plt.title("Age Young To Old")
plt.xlabel("Age Range")
plt.ylabel("Number Of Runners Per Age Group");

# %%
df_17.corr()
# Out:
#                Age   Overall    Gender  Division
# Age       1.000000  0.259626  0.368879 -0.579735
# Overall   0.259626  1.000000  0.902077  0.449812
# Gender    0.368879  0.902077  1.000000  0.403068
# Division -0.579735  0.449812  0.403068  1.000000

# %%
df_17.plot(kind='scatter', x='Age', y='Overall')
plt.title("Age Times")
plt.xlabel("Age")
plt.ylabel("Overall Standing");

# %%
df_17["State"].value_counts(["Name"])
# Out:
# MA    0.201008
# CA    0.089809
# NY    0.058032
# TX    0.046242
# PA    0.036906
# ON    0.035941
# IL    0.033794
# OH    0.030375
# FL    0.026693
# VA    0.024721
# CO    0.023406
# MI    0.022617
# NC    0.021872
# NJ    0.020863
# QC    0.020513
# WA    0.020381
# MN    0.019417
# UT    0.017532
# MD    0.017357
# WI    0.017182
# CT    0.016524
# NH    0.014201
# GA    0.013894
# OR    0.013675
# AZ    0.011834
# IN    0.011703
# TN    0.010388
# MO    0.008898
# ME    0.008153
# BC    0.007714
#         ...
# KS    0.004032
# LA    0.003857
# NV    0.003726
# NE    0.003726
# OK    0.003550
# VT    0.003506
# AL    0.003506
# NM    0.002849
# AR    0.002455
# NB    0.002455
# AK    0.002279
# DE    0.002060
# WV    0.001797
# HI    0.001622
# MT    0.001578
# SD    0.001490
# MB    0.001315
# ND    0.001271
# MS    0.001183
# NL    0.000920
# WY    0.000920
# PR    0.000920
# SK    0.000745
# PE    0.000614
# AE    0.000219
# YT    0.000131
# VI    0.000088
# AP    0.000088
# ...
